# %%
import numpy as np

# %%
np.ones((2,1))
# Out:
# array([[1.],
#        [1.]])

# %%
np.linspace(1, 10, 5)
# Out:
# array([ 1.  ,  3.25,  5.5 ,  7.75, 10.  ])

# %%
a = np.array([1,2,3,4])
a.reshape(2, 2)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.ones((2,1))
# Out:
# array([[1.],
#        [1.]])

# %%
a = np.array([1,2,3])
b = np.array([[1,2],[3,4]])
o = np.ones((3,3))

# %%
a = np.array([1,2,3])
b = np.array([[1,2],[3,4]])
o = np.arange(0,10,2)

# %%
o
# Out:
# array([0, 2, 4, 6, 8])

# %%
a = np.array([[1,2], [3,4]])
print(a.shape)
# Out:
# (2, 2)

# %%
np.arange(1, 10, 2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
b = np.array([[1,2], [3,4]])
print(b.ndim)
# Out:
# 2

# %%
c = np.array([[1,2], [3,4]])
print(c.shape)
# Out:
# (2, 2)

# %%
 a = np.array([[1,2], [3,4]])
 print(a.size)
# Out:
# 4

# %%
e = np.array([[1,2],
              [3,4]])
s = np.array([[2,3],
             [4,5]])
print(np.sum(e))
print(np.sum(s))
# Out:
# 10
# 14

# %%
e = np.array([[1,2], [3,4]])
print(e.dtype)
# Out:
# int64

# %%
w = np.array([[1,2], [3,4]])
print(np.mean(w))
# Out:
# 2.5

# %%
print(np.max(w))
print(np.min(w))
# Out:
# 4
# 1

# %%
print(w.T)
# Out:
# [[1 3]
#  [2 4]]

# %%
s = np.array([4,2,3,1])
print(np.sort(s))
# Out:
# [1 2 3 4]
